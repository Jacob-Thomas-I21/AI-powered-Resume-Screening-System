# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacob-Thomas-I21/AI-powered-Resume-Screening-System/blob/main/Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the neessary module. Other modules will be imported as per demand for the work.
import numpy as np
import pandas as pd

# %% [markdown]
# **bold text**

# %%
df = pd.read_csv('/content/drive/*/Resume.csv')

# %%
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
print(df.isnull().sum())
# Out:
# ID             0
# Resume_str     0
# Resume_html    0
# Category       0
# dtype: int64

# %%
print(f"Dataset contains {df.shape[0]} resumes and {df.shape[1]} coloumns")
# Out:
# Dataset contains 2484 resumes and 4 coloumns

# %%
df = df.drop(columns=['Resume_html'])

# %%
df.head()
# Out:
#          ID                                         Resume_str Category  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...       HR
# 2  33176873           HR DIRECTOR       Summary      Over 2...       HR
# 3  27018550           HR SPECIALIST       Summary    Dedica...       HR
# 4  17812897           HR MANAGER         Skill Highlights  ...       HR
#
#                                         Clean_Resume  \
# 0  hr administrator marketing associate hr admini...
# 1  hr specialist us hr operation summary versatil...
# 2  hr director summary year experience recruiting...
# 3  hr specialist summary dedicated drive dynamic ...
# 4  hr manager skill highlight hr skill hr departm...
#
#                                         Clean Resume
# 0  hr administrator marketing associate hr admini...
# 1  hr specialist us hr operation summary versatil...
# 2  hr director summary year experience recruiting...
# 3  hr specialist summary dedicated drive dynamic ...
# 4  hr manager skill highlight hr skill hr departm...

# %% [markdown]
# ## **REGex module doubts  go here:-https://www.w3schools.com/python/python_regex.asp**

# %%
import re
# rEGEX OR RE IS A MODULE IN PYTHON WHICH DEALS, SEARCH AND REPLACE FUCNTION LIKE IN MCROSFT OFFICE WORD. iT CAN SEARCH USING words , that start with, to find all words, to split a word and sub or replace a word.

# %%
def clean_text(text): # a user defined fucntion to clean text which can be resued and helps to recall data in an easy way
  text = text.lower() # 1st tep converting all text to lower case.re. sun fnction works liek this . re.sub(pattern(regex pattern to find), replacement(what to replace with ), (text whats the string to process))
  text = re.sub(r'\n+',' ',text) #\n refers to next line to be deleted which has more occurence , where extra lime can be deleted.
  text = re.sub(r'[^a-zA-Z0-9\s]','',text) # ^ means not or negation [] means whats inside.since inside a-z &A-Z &0-9 those will be conserved . while subtituting everything else with ''. r before makes sure \s or \n the '\' in thse commands is considered as special character.
  text = re.sub(r'\s+',' ',text) # removes extra spaces. \s returns extra spaces. replaces extrspaces with one space(' ') using sub function. + sign refers to if the extra spaces is doubted to occur more than oen time.

# %%
import pandas as pd

# %%
df['Clean_Resume'] = df['Resume_str'].apply(clean_text) # clean resume has resuem _Str whcih has been cleaned by clean_text fucntion.
df[['Resume_str','Clean_Resume']].head()
# Out:
#                                           Resume_str Clean_Resume
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...         None
# 1           HR SPECIALIST, US HR OPERATIONS      ...         None
# 2           HR DIRECTOR       Summary      Over 2...         None
# 3           HR SPECIALIST       Summary    Dedica...         None
# 4           HR MANAGER         Skill Highlights  ...         None

# %% [markdown]
# Module is a .py file with collection functions and global variables.**e,g, demo_module, random ,re, html.**
# Packages is a collection of modules with a intepreter file. **numpy , pandas are all packages.**
# Library is a chunk of code or collection of packages that can be used to perform fucntions without repeating. eg. **matplotlib,pytorch etc..**
# https://learnpython.com/blog/python-modules-packages-libraries-frameworks/
#
# Module = Your fingers
#
# Package= Your hands
#
# Library = Building your home
#
# Framework = Buying a home **e.g DJANGO , FLASK **
#
# difference between frameworka nd library is that when I build a library i control when the package flow and application, when and where ot acess and control the library. in a framework its flo wis managed by itself.

# %%
import spacy # a nlp processing LIBRARY helps in tokenisation (helps hide senstive info ith non sensitive characters.)
import nltk # like spacy ntlk is also a a library for natural language processing . only difference is ntlk is desiggned for research and spacy for perfomance.
from nltk.corpus import stopwords

# %%
#Work starts.....
nlp = spacy.load("en_core_web_sm") #Loads nlp models.This model is used for tokenization, part-of-speech tagging, dependency parsing, and lemmatization.
nltk.download("stopwords") #Stopwords are words that are filtered out (e.g., “a,” “the,” “and”) because they don’t contribute much meaning.
stop_words = set(stopwords.words("english")) # storing them as a set for fats lookup .
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# In the abbove step we split the resuem into words which can be processed. so the pre rocessing fucntion is as follows.

# %%
def preprocessing(text): # creation of pre process fucntion
  if not isinstance(text,str): # isinstance is a fucntion in python which return for type of object. in this case isinstance(text(object),str(type of object))
    print(f"Skipping a non-string value : {text}")
    return ""
  doc = nlp(text.lower()) # lower all text cases.
  tokens = [token.lemma_ for token in doc if token.is_alpha and token.text not in stop_words] #token.lemma converts words to base form ."for token in doc" calls each word in doc(which is the lowercase text), then token.is_alpha Returns True if the token consists only of alphabetic characters (A-Z or a-z). and token.text in stopwords removes common words such as than , the etc..

  processed_text = " ".join(tokens) # joins the tokens
  print(f"Processed text: {processed_text[:100]}") # print fitst 100 words.
  return processed_text

# %% [markdown]
# Here the fucntion works liek this , it checks the list for all text , if the text is not a string it ll skip and and it will print skipping the non instrang value which is "non -string value". then it eill turn the text into lower case. then token . lemma converts words to bae form such running ot run , managed to manage . etcc. rest of the line of code removes the commond words such as the, than etcc then token.is_alpha converts the words to token .
# then joins these token and ends the funtion and processed_text has all the joined token

# %%
#lets try a sample for pratice
sample = df["Resume_str"].iloc[0]
sample_doc = nlp(sample.lower())
print("Toekans are :",[token.text for token in sample_doc])
print(f"Lemmas are :",[token.lemma_ for token in sample_doc] )
# Out:
# Toekans are : ['         ', 'hr', 'administrator', '/', 'marketing', 'associate', '\n\n', 'hr', 'administrator', '      ', 'summary', '    ', 'dedicated', 'customer', 'service', 'manager', 'with', '15', '+', 'years', 'of', 'experience', 'in', 'hospitality', 'and', 'customer', 'service', 'management', '.', '  ', 'respected', 'builder', 'and', 'leader', 'of', 'customer', '-', 'focused', 'teams', ';', 'strives', 'to', 'instill', 'a', 'shared', ',', 'enthusiastic', 'commitment', 'to', 'customer', 'service', '.', '        ', 'highlights', '        ', 'focused', 'on', 'customer', 'satisfaction', ' ', 'team', 'management', ' ', 'marketing', 'savvy', ' ', 'conflict', 'resolution', 'techniques', '    ', 'training', 'and', 'development', ' ', 'skilled', 'multi', '-', 'tasker', ' ', 'client', 'relations', 'specialist', '          ', 'accomplishments', '     ', 'missouri', 'dot', 'supervisor', 'training', 'certification', ' ', 'certified', 'by', 'ihg', 'in', 'customer', 'loyalty', 'and', 'marketing', 'by', 'segment', '  ', 'hilton', 'worldwide', 'general', 'manager', 'training', 'certification', ' ', 'accomplished', 'trainer', 'for', 'cross', 'server', 'hospitality', 'systems', 'such', 'as', '   ', 'hilton', 'onq', ' ', ',', '  ', 'micros', '   ', 'opera', 'pms', '  ', ',', 'fidelio', '   ', 'opera', '   ', 'reservation', 'system', '(', 'ors', ')', ',', '  ', 'holidex', '   ', 'completed', 'courses', 'and', 'seminars', 'in', 'customer', 'service', ',', 'sales', 'strategies', ',', 'inventory', 'control', ',', 'loss', 'prevention', ',', 'safety', ',', 'time', 'management', ',', 'leadership', 'and', 'performance', 'assessment', '.', '       ', 'experience', '     ', 'hr', 'administrator', '/', 'marketing', 'associate', '\n\n', 'hr', 'administrator', '    ', 'dec', '2013', '  ', 'to', '  ', 'current', '     ', 'company', 'name', '  ', '－', '  ', 'city', ' ', ',', '  ', 'state', '    ', 'helps', 'to', 'develop', 'policies', ',', 'directs', 'and', 'coordinates', 'activities', 'such', 'as', 'employment', ',', 'compensation', ',', 'labor', 'relations', ',', 'benefits', ',', 'training', ',', 'and', 'employee', 'services', '.', ' ', 'prepares', 'employee', 'separation', 'notices', 'and', 'related', 'documentation', ' ', 'keeps', 'records', 'of', 'benefits', 'plans', 'participation', 'such', 'as', 'insurance', 'and', 'pension', 'plan', ',', 'personnel', 'transactions', 'such', 'as', 'hires', ',', 'promotions', ',', 'transfers', ',', 'performance', 'reviews', ',', 'and', 'terminations', ',', 'and', 'employee', 'statistics', 'for', 'government', 'reporting', '.', ' ', 'advises', 'management', 'in', 'appropriate', 'resolution', 'of', 'employee', 'relations', 'issues', '.', ' ', 'administers', 'benefits', 'programs', 'such', 'as', 'life', ',', 'health', ',', 'dental', ',', 'insurance', ',', 'pension', 'plans', ',', 'vacation', ',', 'sick', 'leave', ',', 'leave', 'of', 'absence', ',', 'and', 'employee', 'assistance', '.', '    ', 'marketing', 'associate', '\xa0   ', 'designed', 'and', 'created', 'marketing', 'collateral', 'for', 'sales', 'meetings', ',', 'trade', 'shows', 'and', 'company', 'executives', '.', ' ', 'managed', 'the', 'in', '-', 'house', 'advertising', 'program', 'consisting', 'of', 'print', 'and', 'media', 'collateral', 'pieces', '.', ' ', 'assisted', 'in', 'the', 'complete', 'design', 'and', 'launch', 'of', 'the', 'company', "'s", 'website', 'in', '2', 'months', '.', ' ', 'created', 'an', 'official', 'company', 'page', 'on', 'facebook', 'to', 'facilitate', 'interaction', 'with', 'customers', '.', ' ', 'analyzed', 'ratings', 'and', 'programming', 'features', 'of', 'competitors', 'to', 'evaluate', 'the', 'effectiveness', 'of', 'marketing', 'strategies', '.', '        ', 'advanced', 'medical', 'claims', 'analyst', '    ', 'mar', '2012', '  ', 'to', '  ', 'dec', '2013', '     ', 'company', 'name', '  ', '－', '  ', 'city', ' ', ',', '  ', 'state', '    ', 'reviewed', 'medical', 'bills', 'for', 'the', 'accuracy', 'of', 'the', 'treatments', ',',  ...
# Lemmas are : ['         ', 'hr', 'administrator', '/', 'marketing', 'associate', '\n\n', 'hr', 'administrator', '      ', 'summary', '    ', 'dedicated', 'customer', 'service', 'manager', 'with', '15', '+', 'year', 'of', 'experience', 'in', 'hospitality', 'and', 'customer', 'service', 'management', '.', '  ', 'respect', 'builder', 'and', 'leader', 'of', 'customer', '-', 'focus', 'team', ';', 'strive', 'to', 'instill', 'a', 'share', ',', 'enthusiastic', 'commitment', 'to', 'customer', 'service', '.', '        ', 'highlight', '        ', 'focus', 'on', 'customer', 'satisfaction', ' ', 'team', 'management', ' ', 'marketing', 'savvy', ' ', 'conflict', 'resolution', 'technique', '    ', 'training', 'and', 'development', ' ', 'skilled', 'multi', '-', 'tasker', ' ', 'client', 'relation', 'specialist', '          ', 'accomplishment', '     ', 'missouri', 'dot', 'supervisor', 'training', 'certification', ' ', 'certify', 'by', 'ihg', 'in', 'customer', 'loyalty', 'and', 'marketing', 'by', 'segment', '  ', 'hilton', 'worldwide', 'general', 'manager', 'training', 'certification', ' ', 'accomplish', 'trainer', 'for', 'cross', 'server', 'hospitality', 'system', 'such', 'as', '   ', 'hilton', 'onq', ' ', ',', '  ', 'micro', '   ', 'opera', 'pm', '  ', ',', 'fidelio', '   ', 'opera', '   ', 'reservation', 'system', '(', 'ors', ')', ',', '  ', 'holidex', '   ', 'complete', 'course', 'and', 'seminar', 'in', 'customer', 'service', ',', 'sale', 'strategy', ',', 'inventory', 'control', ',', 'loss', 'prevention', ',', 'safety', ',', 'time', 'management', ',', 'leadership', 'and', 'performance', 'assessment', '.', '       ', 'experience', '     ', 'hr', 'administrator', '/', 'marketing', 'associate', '\n\n', 'hr', 'administrator', '    ', 'dec', '2013', '  ', 'to', '  ', 'current', '     ', 'company', 'name', '  ', '－', '  ', 'city', ' ', ',', '  ', 'state', '    ', 'help', 'to', 'develop', 'policy', ',', 'direct', 'and', 'coordinate', 'activity', 'such', 'as', 'employment', ',', 'compensation', ',', 'labor', 'relation', ',', 'benefit', ',', 'training', ',', 'and', 'employee', 'service', '.', ' ', 'prepare', 'employee', 'separation', 'notice', 'and', 'related', 'documentation', ' ', 'keep', 'record', 'of', 'benefit', 'plan', 'participation', 'such', 'as', 'insurance', 'and', 'pension', 'plan', ',', 'personnel', 'transaction', 'such', 'as', 'hire', ',', 'promotion', ',', 'transfer', ',', 'performance', 'review', ',', 'and', 'termination', ',', 'and', 'employee', 'statistic', 'for', 'government', 'reporting', '.', ' ', 'advise', 'management', 'in', 'appropriate', 'resolution', 'of', 'employee', 'relation', 'issue', '.', ' ', 'administer', 'benefit', 'program', 'such', 'as', 'life', ',', 'health', ',', 'dental', ',', 'insurance', ',', 'pension', 'plan', ',', 'vacation', ',', 'sick', 'leave', ',', 'leave', 'of', 'absence', ',', 'and', 'employee', 'assistance', '.', '    ', 'marketing', 'associate', '\xa0   ', 'design', 'and', 'create', 'marketing', 'collateral', 'for', 'sale', 'meeting', ',', 'trade', 'show', 'and', 'company', 'executive', '.', ' ', 'manage', 'the', 'in', '-', 'house', 'advertising', 'program', 'consist', 'of', 'print', 'and', 'medium', 'collateral', 'piece', '.', ' ', 'assist', 'in', 'the', 'complete', 'design', 'and', 'launch', 'of', 'the', 'company', "'s", 'website', 'in', '2', 'month', '.', ' ', 'create', 'an', 'official', 'company', 'page', 'on', 'facebook', 'to', 'facilitate', 'interaction', 'with', 'customer', '.', ' ', 'analyze', 'rating', 'and', 'programming', 'feature', 'of', 'competitor', 'to', 'evaluate', 'the', 'effectiveness', 'of', 'marketing', 'strategy', '.', '        ', 'advanced', 'medical', 'claim', 'analyst', '    ', 'mar', '2012', '  ', 'to', '  ', 'dec', '2013', '     ', 'company', 'name', '  ', '－', '  ', 'city', ' ', ',', '  ', 'state', '    ', 'review', 'medical', 'bill', 'for', 'the', 'accuracy', 'of', 'the', 'treatment', ',', 'test', ',', 'and', 'hospital', 'stay', 'prior', 'to', 'sanction', 'the', 'claim', '. ...

# %%
#lets to do it with function
sample_run = preprocessing(sample)
# Out:
# Processed text: hr administrator marketing associate hr administrator summary dedicated customer service manager yea

# %%
# Applying the fucntion
df["Clean_Resume"]= df["Resume_str"].apply(preprocessing)
# Out:
# Processed text: hr administrator marketing associate hr administrator summary dedicated customer service manager yea
# Processed text: hr specialist us hr operation summary versatile medium professional background communication marketi
# Processed text: hr director summary year experience recruiting plus year human resource executive management year hr
# Processed text: hr specialist summary dedicated drive dynamic year customer service expertise motivate maintain cust
# Processed text: hr manager skill highlight hr skill hr department startup three new organization startup employment
# Processed text: hr generalist summary dedicated focus administrative assistant excel prioritize complete multiple ta
# Processed text: hr manager summary human resource manager extensive background administrative duty include experienc
# Processed text: hr manager professional summary senior hr professional continuous improvement approach build support
# Processed text: hr specialist summary possess year experience hr classification compensation lead hr specialist recr
# Processed text: hr clerk summary translate business vision hr initiative improve performance profitability growth em
# Processed text: hr assistant summary highly motivated dynamic human resource professional diverse credential seek po
# Processed text: hr manager summary human resource manager practical understanding business need area expertise inclu
# Processed text: hr manager summary obtain position offer many opportunity growth development enhance exist knowledge
# Processed text: hr generalist summary people orient result drive professional outstanding communication skill extens
# Processed text: hr coordinator summary applicant screening background check benefit administration compliance compen
# Processed text: hr clerk summary ethical team orient policy drive individual experience ap ar human resource adminis
# Processed text: hr analyst summary experience professional background human resource administrative customer service
# Processed text: hr director summary human resource professional confident resourceful human resource professional ac
# Processed text: hr generalist recruiter summary human resource generalist great communicator negotiator strong confl
# Processed text: hr consulting summary year experience hr partner experience facet human resource function extensive
# Processed text: hr generalist summary young dedicated focused office administrative assistant excel prioritize compl
# Processed text: hr associate professional summary enthusiastic goal orient hr professional year experience drive inn
# Processed text: hr specialist summary human resource specialist year recruitment federal employment process energeti
# Processed text: hr coordinator summary certify human resource professional extensive employee relation experience fu
# Processed text: hr generalist summary energetic bilingual human resource professional offering year extensive succes
# Processed text: hr coordinator professional summary highly efficient hr coordinator well establish administrative en
# Processed text: hr manager generalist summary background progressively responsible human resource experience union n
# Processed text: hr representative summary experience human resource professional work knowledge state federal employ
# Processed text: hr director administrator executive profile self motivate individual year experience successfully ma
# Processed text: hr intern summary enthusiastic student highly motivated commit develop personally professionally abi
# Processed text: hr assistant highlight interview expertise employee relation manager coaching training event managem
# Processed text: hr generalist professional profile responsible administrative support professional extensive experie
# Processed text: hr manager executive profile accomplish hr professional experience strategic planning organizational
# Processed text: hr consultant summary detail orient year human resource professional excel tight deadline anticipate
# Processed text: hr coordinator summary obtain challenging career human resource field utilize capability experience
# Processed text: hr manager summary human resource professional practical understanding business need area expertise
# Processed text: hr generalist summary human resource manager add value contribute company growth profitability trust
# Processed text: hr partner summary experience human resource business partner expertise partnering line business lea
# Processed text: hr specialist summary energetic administrative assistant year experience high level executive suppor
# Processed text: hr director professional summary experienced hr manager facility year proven hr experience area empl
# Processed text: hr executive summary dual specialization domain human resource management finance highlight human re
# Processed text: hr executive professional summary forward think hr generalist highly effective adapt evolve market p
# Processed text: hr generalist skill microsoft office suite sap kronos ibm adp ats mss hrss oracle workbrain experien
# Processed text: hr assistant professional profile skilled program coordinator bring extensive background technology
# Processed text: hr coordinator summary highly accomplish human resource professional proficient develop policy stand
# Processed text: hr coordinator summary motivate professional seek career outside sale self start drive persuasive po
# Processed text: hr generalist experience current hr generalist company name city state recruit help open new company
# Processed text: hr consultant summary subject matter expert hr application highly effective incorporate creative sol
# Processed text: hr generalist experience current provide general administrative support prepare correspondence form
# Processed text: hr intern summary highly drive recruiter maintain positive attitude pressure welcome challenge respo
# Processed text: hr assistant payroll highlight paychex mastertax abra time star infotronic store master dominion qui
# Processed text: hr assistant summary hard worker dedicated detailed orient experienced organized highly motivated ma
# Processed text: hr generalist professional summary year experience human resource benefit administration employee re
# Processed text: hr representative summary motivated business partner communicate collaborate effectively level perso
# Processed text: hr specialist summary result drive professional comprehensive experience human resource customer ser
# Processed text: hr manager highlight senior human resource strategist recruitment manager talent management strategi
# Processed text: senior hr highlight safety managementemployee engagementhr generalisttraining developmentorganizatio
# Processed text: hr generalist professional summary dependable responsible human resource generalist fourteen year ex
# Processed text: hr consultant summary certify human resource professional year background full range hr function ext
# Processed text: hr associate summary innovative artistic professional year fashion industry energetic recruiter self
# Processed text: hr coordinator summary obtain human resource generalist position fully utilize extensive background
# Processed text: summary chicago hr generalist offer recruitment attendance management system payroll processing mis
# Processed text: hr specialist highlight staffing recruit professional interview expertise recruit personnel record m
# Processed text: hr administrator summary experience recruiting coordinator year support various industry expert mana
# Processed text: hr manager summary hr coordinator motivate create collaborative team environment use background orga
# Processed text: hr consulting summary year experience hr partner experience facet human resource function extensive
# Processed text: hr assistant professional summary hr assistant reflect value excellence quality provide excellent cu
# Processed text: hr manager summary human resource professional ability work successfully level organization deliver
# Processed text: hr director summary hr professional offering year progressive experience include extensive practice
# Processed text: hr professional summary dependable self motivated assertive human resource professional innovative s
# Processed text: hr coordinator summary first job retail salesperson passion leadership development other human resou
# Processed text: hr generalist summary hr generalist yrs professional experience employee recruitment orientation eng
# Processed text: senior hr manager hr business partner summary highly dedicated accomplish human resource manager rec
# Processed text: hr assistant iii certification john logan college university alabama birmingham professional summary
# Processed text: hr accounting representative summary diverse experience accounting credit union financial service re
# Processed text: sr hr generalist summary quality drive analytical professional deliver consistent successful result
# Processed text: directv hr administration summary goal obtain position utilize enhance education skill highlight exc
# Processed text: hr business partner summary proactive human resource business partner guide performance management t
# Processed text: assistant manager hr professional summary look challenging position utilize skill hard work provide
# Processed text: hr associate mobilization coordinator summary professional extensive experience human resource oil g
# Processed text: regional hr manager summary holistic hr professional year month experience human resource vertical a
# Processed text: field hr associate summary reliable hr field associate master science human resource management emph
# Processed text: hr employee relation specialist summary dedicated self motivate professional experience provide outs
# Processed text: territory hr manager executive profile territory human resource manager offer outstanding presentati
# Processed text: general hr assistant office assistant summary effective communicator team leader excellent time mana
# Processed text: senior hr business partner summary human resource professional year experience human resource recrui
# Processed text: hr business partner ii summary obtain position human resource field utilize prove people orient skil
# Processed text: recruiting hr manager summary experience corporate recruiter self motivate result drive highly respo
# Processed text: regional hr deputy manager summary competent hr generalist seasoned recruiter extensive background h
# Processed text: sr hr consultant executive profile ambitious human resource professional create strategic alliance o
# Processed text: hr share service analyst summary versatile hr professional strong benefit administration background
# Processed text: volunteer hr summary sponsorship require work us successful human resource professional master quali
# Processed text: global hr manager summary global hr professional year progressive experience across industry geograp
# Processed text: hr safety manager summary human resource manager certify professional human resource phr extensive b
# Processed text: hr specialist information system experience company name city state hr specialist information system
# Processed text: director hr executive profile ambitious human resource generalist create strategic alliance organiza
# Processed text: hr senior specialist career overview dedicate service representative professional motivate maintain
# Processed text: hr customer service representative summary excellent team player legal background ability interpret
# Processed text: hr service representative summary multi skilled professional good round hr imformatory skill capable
# Processed text: hr assistant intern summary new graduate seek work counselor able facilitate individual group therap
# Processed text: hr benefit leave coordinator summary year human resource experience year administrative experience w
# Processed text: regional hr business partner human resource professional executive profile business savvy result dri
# Processed text: hr personnel assistant summary citizen authorize work us employer work year office clerk year studen
# Processed text: executive assistant hr summary skillful dedicated executive assistant extensive experience coordinat
# Processed text: senior hr manager professional summary result drive business orient professional strong experience b
# Processed text: hr manager business partner summary human resource business partner extensive experience align hr st
# Processed text: designation hr assistant professional summary human resource coordination management professional of
# Processed text: hr volunteer asst manager professional summary dedicate every project work strong undergraduate grad
# Processed text: hr horizontal engineer professional summary passionate hr specialist year extensive experience compl
# Processed text: hr contact center specialist summary forward think professional various experience human resource sa
# Processed text: designer summary designer year product design manufacturing exhibit design visual merchandising comp
# Processed text: designer summary establish well round designer reputation exquisitely design collection consistently
# Processed text: designer summary get strong foothold career ladder good company support teamwork utilize ability emp
# Processed text: designer technical designer summary creative fashion designer background catagorie swim intimate app
# Processed text: multimedia designer graphic designer portfolio summary hardworking focused determined artist look ob
# Processed text: graphic designer summary graphic designer creative detail orient think lot want make thing clear sim
# Processed text: e learn designer career overview highly skilled experienced educator strong background information t
# Processed text: graphic designer summary enthusiastic student major chemistry great perform many task timely matter
# Processed text: technical designer summary special qualification textile engineering knitting garment manufacturing
# Processed text: mechanical designer summary current mechanical designer extremely versatile reliable efficient year
# Processed text: website designer summary software developer well verse entire workflow develop implement website inc
# Processed text: floral designer summary involve retail industry year year employ sale associate floral designer also
# Processed text: instructional designer summary tamantha uebele home health clinical analyst instructional designer y
# Processed text: instructional designer summary dependable resourceful instructor trainer technical writer instructio
# Processed text: technical designer career overview year experience software developer java technology present techni
# Processed text: instructional designer summary motivating talented instructional designer drive inspire student purs
# Processed text: product designer professional summary year engineering experience year working experience able work
# Processed text: form designer professional summary professionally train job title experience ensure high standard cu
# Processed text: information designer summary qualification strong leadership project management system administratio
# Processed text: independent designer professional summary independent result drive design professional extensive bac
# Processed text: graphic designer experience graphic designer january january company name city state personal intere
# Processed text: graphic designer summary multi talented graphic designer consistently motivate success goal drive sk
# Processed text: web designer professional summary train quality assurance specialist demonstrate history work pharma
# Processed text: floral designer summary floral designer six year experience artistically arrange real flower leave d
# Processed text: vr designer summary game designer exceptional modeling prioritization skill look career organization
# Processed text: mechanical designer professional profile design engineer prove track record success offer excellence
# Processed text: floral designer summary retail floral designer energetic outgoing detail orient handle multiple resp
# Processed text: solution designer career overview solution orient consultant possess unique combination skill includ
# Processed text: graphic designer summary hardworking multi talented individual love design play sport learn always c
# Processed text: interior designer summary result orient designer objective evolve creatively field interior design e
# Processed text: interior designer objective obtain position reputed organization utilize skill contribute organizati
# Processed text: graphic designer summary drive graphic artist adept manage heavy workload focus design creative visu
# Processed text: cad designer summary personable cad designer drafter communicate openly effectively involve construc
# Processed text: interior designer summary talented designer retail merchandiser skilled use product placement create
# Processed text: project designer summary team orient client focus civil engineer year experience design environmenta
# Processed text: graphic designer professional summary hi designer strong passion profession excellent qualification
# Processed text: interior designer professional summary hand highly motivated interior designer involve stage design
# Processed text: lighting designer professional summary computer savvy proficient design tool architecture electro me
# Processed text: instructional designer professional summary instructional design position work medium large company
# Processed text: set designer summary visual merchandiser commit stay current market trend consumer interest collabor
# Processed text: graphic designer summary versatile professional hand leader motivate train coach employee drive prog
# Processed text: graphic designer summary highly creative multi talented graphic designer year multi media graphic de
# Processed text: freelance designer summary multi disciplinary designer strong marketing entrepreneurial background e
# Processed text: floral designer skill billing cash handling cashier creativity customer service magic pick pos exper
# Processed text: instructional designer summary dedicated efficient versatile professional credit combine project man
# Processed text: designer professional profile experience mechanical designer create high quality cad model engineeri
# Processed text: architectural designer summary three year experience demonstrating consistency outstanding work desi
# Processed text: interior designer summary successful design consultant year experience manage large scale interior e
# Processed text: mechanical designer summary offer twenty eight year extensive work knowledge principle theory concep
# Processed text: graphic designer summary work front desk receptionist meyer sound contribute marketing team update t
# Processed text: floral designer summary personable customer service associate dedicate provide high level customer s
# Processed text: presentation designer summary customer service retail design technology particular talent build soli
# Processed text: salon designer career overview commit motivate exceptional customer service decision making skill st
# Processed text: lead designer career focus professional experience deal optimization complex process system well pro
# Processed text: cad designer skill catia solidwork inventor pro e wildfire creo production floor support design manu
# Processed text: production designer summary specialize art department many different opportunity well many different
# Processed text: solution designer summary seek planning engineer position utilize skill ability industry offer secur
# Processed text: designer stylist summary high achieve sale associate offer extensive background customer service sal
# Processed text: digital designer summary city state zip code phone number email date name title organization address
# Processed text: cad designer summary seek position respected company allow contribute success work cohesive environm
# Processed text: graphic designer personal information date birth may present resident triangle va soon montclair va
# Processed text: interior designer summary head designer realtor developer work create space collaborate contractor a
# Processed text: electrical cad designer summary highly motivated team player vast skill set strong work ethic profic
# Processed text: job captain designer highlight software literacy autocad aperture microstation adobe illustrator pho
# Processed text: technical instructional designer professional summary enthusiastic hard working former military trai
# Processed text: apparel technical designer career focus represent company interest universal consistent fit aestheti
# Processed text: freelance ux ui interaction designer summary combine work experience architecture move forward new c
# Processed text: project manager cad designer experience current project manager cad designer company name oversee ma
# Processed text: freelance graphic designer highlight summary marketing design professional nearly eight year experie
# Processed text: marketing coordinator graphic designer professional summary passionate person two year experience ma
# Processed text: jewelry designer owner summary skillful dedicated executive assistant extensive experience coordinat
# Processed text: lead piping designer summary senior mechanical piping designer year progressive design experience pe
# Processed text: lead interaction designer summary senior ux ui designer profile tim involve user center design year
# Processed text: kichen bath designer sale professional summary experience phase architectural interior design year b
# Processed text: senior interior designer professional summary interior designer diverse experience work commercial p
# Processed text: senior product designer professional summary prove experience product designer involve every phase p
# Processed text: senior graphic designer summary diverse result orient graphic designer year experience print logo de
# Processed text: personal woman designer summary eager work fast pace customer focus environment drive expand sale vo
# Processed text: r graphic artist designer focus graphic design digital art graphic designer skilled digital art conc
# Processed text: pre press graphic designer summary creative hardworke designer seek full time desktop job educate gr
# Processed text: senior interior designer summary experience interior designer diverse knowledge base design style te
# Processed text: graphic designer illustrator summary raise christian home jacksonville florida move birmingham atten
# Processed text: principle designer owner professional summary interior designer distinct understanding spatial theor
# Processed text: zachory edmiston summary skilled customer service motivate enhance customer loyalty exceptional serv
# Processed text: program manager designer professional summary talented program designer learn specialist experience
# Processed text: senior technical designer summary product developer technical designer strength apparel handbag jewe
# Processed text: graphic designer summary seek position experience use make positive contribution skill photoshop ind
# Processed text: creative graphic designer summary review post much interest please take consideration qualification
# Processed text: sr graphic designer summary work graphic designer vanderbilt university twenty year additionally sin
# Processed text: lead ux ui designer executive profile insightful ux ui designer experience agile waterfall environme
# Processed text: freelance graphic designer highlight web print design skill software visual element image photo layo
# Processed text: marketing specialist graphic designer professional summary accomplished creative marketing professio
# Processed text: freelance graphic designer summary accomplish graphic designer year experience graphic design camera
# Processed text: senior interior designer highlight microsoft office suite apple iwork suite autodesk autocad archite
# Processed text: branch manager floral designer summary branch manager drive exceed sale goal build long term relatio
# Processed text: freelance website designer summary marine corps train leader business development specialist extensi
# Processed text: web designer graphic designer summary obtain dynamic challenging opportunity contribute success busi
# Processed text: nx unigraphic designer summary highlight virus spyware removal highly motivated resourceful organize
# Processed text: product web designer summary career year include graphic art field fine art elementary art teacher p
# Processed text: project manager instructional designer summary dependable resourceful project manager instructional
# Processed text: senior industrial designer professional summary pleased submit resume product designer skip hop inc
# Processed text: lead senior graphic designer summary manage multiple project cross channel marketing message brandin
# Processed text: sale consultant interior designer professional summary result orient sale professional eager join re
# Processed text: osp engineering designer experience osp engineering designer current company name city state complet
# Processed text: senior digital designer experience current senior digital designer company name city state provide d
# Processed text: fine jewelry cad designer summary two year experience fine jewelry cad designer seven year experienc
# Processed text: lead instructional designer summary instructional system designer distinguished successful experienc
# Processed text: information technology summary dedicate information assurance professional well verse analyze mitiga
# Processed text: information technology specialist experience current information technology specialist company name
# Processed text: information technology supervisor summary seek position information technology specialist year infor
# Processed text: information technology instructor summary seventeen year experience information technology field sev
# Processed text: information technology manager analyst professional summary innovative solution focus web developmen
# Processed text: christopher towne summary knowledgeable information technology specialist capable set optimize works
# Processed text: information technology auditor skill peoplesoft hcm peoplesoft financial peopletool sql developer ms
# Processed text: director information technology career overview seek position director company able utilize experien
# Processed text: information technology provision technician career overview process drive goal orient information se
# Processed text: information technology specialist experience information technology specialist january company name
# Processed text: information technology manager experience information technology manager april current company name
# Processed text: director information technology professional profile senior project management position senior proje
# Processed text: information technology manager qualification strong communication skill web application design work
# Processed text: experience information technology manager experience experience information technology manager highl
# Processed text: information technology manager summary successful fifteen year experience management technical suppo
# Processed text: information technology specialist professional summary experienced network professional outstanding
# Processed text: director information technology professional summary result drive director year experience diverse i
# Processed text: information technology specialist system analysis summary year professional service information tech
# Processed text: information technology coordinator professional summary highly talented accomplish paralegal extensi
# Processed text: director information technology executive profile director information technology project manager bu
# Processed text: information technology specialist professional summary skill account management cable cable help des
# Processed text: information technology certify technician summary nineteen year experience information technology pr
# Processed text: vp information technology executive profile result orient technology leader year experience year sup
# Processed text: information technology intern professional profile obtain full time entry level information technolo
# Processed text: information technology manager professional summary possess extensive background information technol
# Processed text: administrator information technology summary advanced desktop support lead manager plus year experie
# Processed text: director information technology profile summar apply technology workflow solution business challenge
# Processed text: vice president information technology executive profile performance drive executive experience build
# Processed text: information technology senior manager summary year leadership experience information technology dire
# Processed text: information technology specialist career overview temporary permanent service representative profile
# Processed text: information technology coordinator career overview avp director information technology network engin
# Processed text: information technology specialist summary recent graduate seek opportunity hardware software support
# Processed text: objective obtain position information technology personnel development computer science field help m
# Processed text: senior director information technology executive profile distinguish director information technology
# Processed text: director information technology summary director manager extensive experience network operation leve
# Processed text: information technology internship summary mba graduate specialize business management industry insti
# Processed text: information technology specialist professional profile quality drive practical system administrator
# Processed text: information technology summary obsess technology power change everything technology fuel passion com
# Processed text: information technology specialist professional summary seek obtain career information assurance focu
# Processed text: information technology analyst summary pursue caring creative career apply exist knowledge acquire n
# Processed text: information technology consultant highlight software ms word outlook powerpoint excel access crm ado
# Processed text: information technology specialist career overview permanent certification itnw comptia itmt ms manag
# Processed text: information technology specialist professional summary secure position information technology challe
# Processed text: information technology specialist summary certify lan wan frame relay tcp ip iava router firewall sw
# Processed text: information technology specialist infosec summary retire information assurance system security certi
# Processed text: information technology director experience information technology director april january company nam
# Processed text: information technology specialist summary organized dba professional hand experience support oracle
# Processed text: information technology specialist summary information security analyst system professional year dive
# Processed text: information technology student career overview result drive database administrator extensive educati
# Processed text: director information technology executive profile performance drive accomplished director informatio
# Processed text: director information technology professional summary dynamic information technology manager year lea
# Processed text: information technology project manager summary summary skilled professional year proven success deve
# Processed text: information technology specialist experience information technology specialist company name state bu
# Processed text: director information technology summary solution orient professional solid experience various enviro
# Processed text: epic information technology specialist summary seek position field bio pharma utilize contribute ski
# Processed text: information technology manager summary dedicate manager well verse analyze mitigate risk find cost e
# Processed text: director information technology executive profile innovative executive technology professional stron
# Processed text: senior information technology manager executive summary result focus information technology manageme
# Processed text: information technology specialist summary twelve year experience provide high quality consulting tec
# Processed text: information technology specialist summary highly skilled result orient specialist extensive experien
# Processed text: information technology administrator professional profile jack trade guy one premier intellectual pr
# Processed text: information technology manager summary experience information technology manager commit maintain inn
# Processed text: information technology specialist professional profile continue work information technology field de
# Processed text: information technology coordinator professional profile graduate record success implement solution d
# Processed text: information technology consultant career overview accomplish information technology professional yea
# Processed text: information technology technician summary versatile system administrator possess superior troublesho
# Processed text: lead information technology support specialist work history company name company name skill applicat
# Processed text: assistant information technology director summary high perform energetic portfolio program project m
# Processed text: branch chief information technology specialist profile motivated information technology cyber securi
# Processed text: information technology consultant manage member summary versatile analytic specialist prove record s
# Processed text: senior vp information technology executive profile core skill demonstrate ability strong leader fast
# Processed text: information technology help desk specialist highlight microsoft window operating system xp windows a
# Processed text: information technology specialist web career overview objective specialist custspt noc experience sy
# Processed text: information technology bureau deputy director professional summary senior information technology pro
# Processed text: ea information technology specialist iii drupal dev summary drupal developer five year experience si
# Processed text: head information technology information center executive profile leader organization year career for
# Processed text: senior vice president global information technology executive profile high energy result orient chie
# Processed text: director information technology technology officer executive profile strategic planning security com
# Processed text: vice president information technology infrastructure operation summary result drive executive manage
# Processed text: information technology specialist information security officer profile blah blah core qualification
# Processed text: information technology intern test automation engineer summary year experience serve key contributor
# Processed text: information technology aws admin intern experience information technology aws admin intern company n
# Processed text: vice president information technology software engineering professional summary result drive busines
# Processed text: information technology manager network engineer professional overview highly skilled accomplished in
# Processed text: director information technology analytic summary accomplish senior manager year experience lead comp
# Processed text: manager information technology project management office professional summary highly motivated drive
# Processed text: information technology project manager system analysis sysanalsys professional overview highly quali
# Processed text: manager information technology building automation system summary manager information technology bui
# Processed text: information technology support specialistnetwork specialist pc technician consultant customer work e
# Processed text: administrative assistant director human resource manager production manager engineering manager summ
# Processed text: customer service representative summary recognize able promote exceptional result productivity team
# Processed text: support technician education bachelor science may william woods university city state gpa gpa manage
# Processed text: database programmer analyst developer summary software engineer year web developer specialize front
# Processed text: consultant experience consultant current company name city state manage project schedule local remot
# Processed text: database programmer analyst developer summary software engineer year web developer specialize front
# Processed text: operation research analyst summary personable project manager successful build strong professional r
# Processed text: production associate summary conclude application letter thank employer consider position include in
# Processed text: management career overview detail orient professional extensive information technology experience ha
# Processed text: work rf system engineer qualification microsoft office office mac page number keynote rf microwave s
# Processed text: business system analyst qualification technical skill business application sap web intelligence info
# Processed text: project manager summary technical support professional skilled resolve complex customer service issu
# Processed text: adjunct instructor skill highlight quality engineering process improvement acceptance test strategic
# Processed text: web developer accomplishment associate month award cyient member team team month award project debt
# Processed text: assistant football coach summary enthusiastic reliable recent graduate academic background business
# Processed text: system administrator experience company name sksit security wireless environment sksit secure wlans
# Processed text: staff assistant professional summary highly organized detail orient staff assistant year experience
# Processed text: support network services intern professional summary technical support analyst technical troubleshoo
# Processed text: manager summary ten year management experience focus team building project management ten year exper
# Processed text: practice manager executive summary strategic motivational solution focused leader mba extensive expe
# Processed text: director accomplishment citrix xenapp basic administration security essential spicework foundation l
# Processed text: freelance consultant career overview highly skilled result drive information technology specialist c
# Processed text: staff pharmacist summary patient professional excellence orient pharmacist doctor pharmacy master sc
# Processed text: senior vice president chief information officer core accomplishment strategize various area business
# Processed text: amc computer specialist intern summary information technology specialist twenty nine year experience
# Processed text: master data manager experience master data manager current company name city state align supply chai
# Processed text: corporate project manager career overview season project manager drive achieve result strategic plan
# Processed text: technology specialist professional summary analyst extensive experience information technology profi
# Processed text: manager highlight customer client relation advanced troubleshooting technique project management tra
# Processed text: subject matter expert information technology assistant qualification sap hp alm network configuratio
# Processed text: training manager executive summary qualified training manager offer record successful job performanc
# Processed text: teacher professional summary master teacher look new role industry look leverage valuable skill know
# Processed text: teacher summary teach grade last fifteen year typically work general education student collaborative
# Processed text: teacher skill chart excellent communication conference conflict resolution critical thinking focus i
# Processed text: teacher summary obtain position work customer service utilize friendly outgoing attitude nalytical a
# Processed text: teacher skill e ducator people skill enthusiasti c problem solve r great organizational skill encour
# Processed text: teacher summary kind compassionate elementary school teacher dedicate create atmosphere stimulate en
# Processed text: teacher farrah bauman professional summary position adjunct teacher professor major responsibility e
# Processed text: teacher professional summary past ten year excel effectively build highly motivated team vary backgr
# Processed text: teacher professional summary exceptional special education professional seek director position passi
# Processed text: teacher summary apply experience elementary level teaching combine history music well alt certificat
# Processed text: teacher core accomplishment girl scout missouri heartland cole county service unit manager community
# Processed text: teacher professional summary experienced human resource training professional demonstrate success de
# Processed text: teacher summary highly ethical dependable diligent expert curriculum development field highlight cur
# Processed text: teacher summary thank take time read present resume express interest social study teach position sch
# Processed text: teacher professional summary savvy teacher superb problem solving seo analytic microsoft office skil
# Processed text: teacher profile highly qualified vocal music teacher hold bs music education kansas state university
# Processed text: teacher summary apply teaching positionchildcare professional skilled remain calm pressure keep dayc
# Processed text: teacher professional summary highly organized detail orient administrative professional year experie
# Processed text: teacher summary kind compassionate elementary middle school teacher dedicate create atmosphere stimu
# Processed text: teacher professional summary enthusiastic highly motivated dedicated instill child passion become li
# Processed text: teacher summary kind compassionate highly motivated teacher dedicate create atmosphere stimulate enc
# Processed text: teacher professional background certify nursing assistant experience serve chronically ill patient i
# Processed text: teacher summary kind compassionate elementary school teacher dedicate create atmosphere stimulate en
# Processed text: teacher interest rangoli dance company los angeles can lead post graduate company dancer present gra
# Processed text: teacher summary experienced detail orient program manager excellent communication problem solve stra
# Processed text: teacher professional summary look position use strong passion child development together skill exper
# Processed text: teacher summary child care professional background family support specialist teacher look join grow
# Processed text: teacher summary talente early education professional diverse experience plan implement various activ
# Processed text: teacher summary experience assistant manager adept problem solving customer service hiring training
# Processed text: teacher executive profile passionate creative leader year experience spearhead special event project
# Processed text: teacher summary seasoned instructor bring year experience teach chemistry physics mathematic knowled
# Processed text: teacher summary seek education coordinator position company allow fully manage curriculum developmen
# Processed text: teacher summary teacher year experience specialty area include classroom management behavioral devel
# Processed text: teacher career overview highly enthusiastic customer service professional year client interface cust
# Processed text: teacher professional summary microbiology emphasis food food protection specialist master science ex
# Processed text: teacher experience teacher company name city state implement instructional activity contribute meani
# Processed text: teacher summary highly motivated hard work medical assistant knowledge technical medical support exc
# Processed text: teacher summary elementary school teacher many year success teaching class develop child learning ab
# Processed text: teacher summary teacher devoted help child think creatively solve problem independently respect othe
# Processed text: teacher willing relocate anywhere professional summary maintain long term position cohesive diverse
# Processed text: teacher summary dedicated teaching counsel educator experience successfully teach english student ch
# Processed text: teacher summary highly enthusiastic motivated responsible caring dedicated commit high school math e
# Processed text: teacher summary education professional drive create environment promote hand learn child stage learn
# Processed text: teacher summary energetic year experience high level executive support role organize professional de
# Processed text: teacher summary committed highly dedicated professional fifteen year extensive experience teaching c
# Processed text: teacher summary accomplish experienced well educate business minded career seeker take great pride e
# Processed text: teacher accomplishment monitor school district delinquent status recommend warrant withhold state fu
# Processed text: teacher summary responsible special education teacher excellent communication skill demonstrate year
# Processed text: teacher summary ath teacher excellent communication skill organize drive innate ability stay task us
# Processed text: teacher facebook email professional summary highly motivated teche professional year experience fast
# Processed text: teacher summary dedicated teacher marine corps veteran experience many different work environment ac
# Processed text: teacher read teacher summary energetic employee year experience administrative dedicated focus emplo
# Processed text: math teacher math intervention teacher summary seek academic advisor position lifelong learner conti
# Processed text: kindergarten teacher summary dedicated educator commit create classroom atmosphere stimulating encou
# Processed text: assistant teacher summary organized professional experience foster cohesive student learning environ
# Processed text: english teacher summary well organize thorough dedicated professional document success undertake var
# Processed text: substitute teacher skill computer literate driver listen natural packaging quality rapport teach exp
# Processed text: substitute teacher skill outlook excel word powerpoint quickbook onenote experience current substitu
# Processed text: pre service teacher summary seek middle grade math science teaching position contribute creativity c
# Processed text: inclusion teacher professional summary highly motivated student focus educator key focus individual
# Processed text: director preschool teacher summary personable education professional drive inspire student achieve p
# Processed text: preschool teacher professional summary efficient accurate detail orient innate drive provide excepti
# Processed text: bi teacher summary motivated teaching professional year experience address student need ensure prope
# Processed text: assistant teacher summary childcare professional skilled remain calm pressure keep daycare set light
# Processed text: lead teacher summary secure position utilize skill work ethic achievement asset company highlight kn
# Processed text: guest teacher professional overview detail orient high energy social science teacher ability motivat
# Processed text: substitute teacher summary health administration hospital operation public service major intelligent
# Processed text: preschool teacher summary enthusiastic preschool teacher talente teach visual art music theater enga
# Processed text: preschool teacher summary short term utilize skill costumer service industry prepare career future l
# Processed text: english teacher summary imaginative teacher commit stay current late teaching theory trend well beha
# Processed text: guest teacher floral designerwrite title certify professional floral designer mentor aifd found memb
# Processed text: assistant teacher summary teacher aide lovingly teach child age month thorough guide child variety d
# Processed text: art teacher summary creative caring leader earn trust respect student colleague administration year
# ...
# Processed text: customer service specialist career overview highly enthusiastic customer service professional year c
# Processed text: dance instructor summary enthusiastic dance instructor superb leadership communication skill easily
# Processed text: inside account manager summary inside account manager eight year experience shi fill inside sale tea
# Processed text: college assistant summary professional leader strong emphasis management initiative focus develop co
# Processed text: assistant acquisition disposition summary acquisition disposition coordinator adept client relation
# Processed text: certify nurse assistant professional summary motivated individual highly effective communication ski
# Processed text: shift supervisor summary service orient shift supervisor year background training worker maintain st
# Processed text: customer service associate cashier summary highly motivate professional seek receptionist position p
# Processed text: medical billing specialist skill highlight microsoft office product word excel access powerpoint typ
# Processed text: administrative assistant summary acquire challenging position reputable agency allow opportunity sho
# Processed text: food server summary sixteen year experience customer service industry experience include customer or
# Processed text: community outreach specialist professional profile dynamic professional drive foster love learn ensu
# Processed text: creative assistant professional summary self motivate individual ability create maintain positive un
# Processed text: library aide full time professional summary high school graduate june accept broward county intern w
# Processed text: audio visual technician summary proficient configuration operation daw software pro tool logic pro m
# Processed text: general manager executive summary secure position respected business benefit organizational leadersh
# Processed text: administrative assistant site clerk career overview commit motivated administrative assistant except
# Processed text: coordinator donor relation summary highly organize communication specialist number year communicatio
# Processed text: dental hygienist professional summary dedicated energetic dental hygienist total sixteen year experi
# Processed text: aviation engineer profile innovative electrical engineer specialize operation orient electrical engi
# Processed text: aviation mechanic skill license faa rate airframe powerplant technician yellow belt lean sigma certi
# Processed text: aviation maintainer professional summary year experience fast food cook assistant manager year exper
# Processed text: aviation mechanic highlight technical proficiency ms office excel outlook powerpoint word accomplish
# Processed text: p aviation supply specialist summary ambitious student pursue computer science degree eager contribu
# Processed text: aviation electronic technician summary seek challenging position exist skill experience contribute c
# Processed text: aviation safety assistant career overview receive telephone call give routine non routine informatio
# Processed text: aviation electronic technician summary administrative advocate lead consistent work ethic attitude p
# Processed text: aviation technician summary grow maintenance background always work vehicle equipment start professi
# Processed text: aviation executive officer summary seasoned leader possess effective decision making analytical orga
# Processed text: aviation supply specialist summary organize professional superior work ethic team player attitude ex
# Processed text: aviation supply specialist summary may concern utmost enthusiasm would like express interest availab
# Processed text: aviation part salesman career focus earn private pilot license august total time hour familiar airsp
# Processed text: aviation supply specialist summary military professional year experience team management administrat
# Processed text: aviation maintenance technician profile forward think aviation maintenance technician hand experienc
# Processed text: aviation operation specialist summary pursue position client support specialist ii along opportunity
# Processed text: aviation camp assistant profile highly motivated result orient individual seek internship aerospace
# Processed text: unmanned aviation technician supervisor summary solution focus versatile management professional off
# Processed text: aviation record analyst summary highly organized detail orient analyst year professional experience
# Processed text: aviation supply technician summary supply chain operation manager invaluable knowledge manage projec
# Processed text: aviation safety assistant summary year customer service experience administrative assistant federal
# Processed text: sergeant aviation supply specialist summary highly motivated ambitious individual able give timely a
# Processed text: director aviation safety skill highlight project management leadership communication skill employee
# Processed text: aviation fuel quality control specialist professional summary dynamic result orient highly talented
# Processed text: aviation maintenance egress lead petty officer lead petty officer summary obtain position utilize un
# Processed text: superintendent ii summary solution focus versatile management professional offer comprehensive backg
# Processed text: quality control inspector summary southeast region veteran preference point preference base disabili
# Processed text: senior manager customer support summary charismatic business professional successful manage business
# Processed text: software engineering co op summary highly skilled accomplished computer software specialist year tec
# Processed text: mechanical engineer summary year month experience mechanical engineer operation maintenance boiler s
# Processed text: outside machinist summary respond great interest advertisement carrier overhaul network scheduling p
# Processed text: plant fulfillment leader summary dedicated leader comprehension manufacturing material inventory exp
# Processed text: network administrator summary analytical network administrator adept resolve complex network issue c
# Processed text: postal support employee summary program manager logistics specialist accomplish veteran united state
# Processed text: air traffic controller summary retire air traffic controller year experience work traffic en route e
# Processed text: concierge doorman summary experience work concierge military general office international domestic s
# Processed text: graduate engineer summary intellectually curious resourceful great interpersonal skill ability commu
# Processed text: lean six sigma black belt summary highly skilled train professional decade experience administrative
# Processed text: assembly mechanic summary aircraft mechanic year experience extensive background rotary wing fixed w
# Processed text: force analyst summary profile honorably discharge navy first class aviation specialist transitioning
# Processed text: lead aerospace assembler summary accomplished highly motivated aerospace assembler technician solid
# Processed text: instructor writer experience instructor writer february current company name city state conduct stud
# Processed text: field project supervisor summary administrative aviation logistic professional year experience work
# Processed text: senior warrant officer advisor summary dedicated experienced personnel manager education administrat
# Processed text: aircraft sale professional summary expect associate professionally drive well respect organization p
# Processed text: planner scheduler summary highly motivate effective communicator problem solver work well team membe
# Processed text: financial technician summary diligent drive financial technician achieve success variety role increa
# Processed text: simulator technician summary experience electronic technician extensive knowledge c c theory trouble
# Processed text: trip coordinator accomplishment develop new process capture procurement minimize work flow time depa
# Processed text: senior supply sergeant objective obtain position logistics arena inventory management specialist log
# Processed text: lead engineer fluid system thermal accessory summary forward think mechanical engineer several year
# Processed text: student professional summary complete bachelor science interdisciplinary social science minor confli
# Processed text: patient care technician summary enthusiastic hardworking nursing school graduate graduate salutatori
# Processed text: global project manager summary background information technology year experience work aviation groun
# Processed text: front desk attendant summary graduate bridgewater state university may bachelor degree aviation mana
# Processed text: quality assurance manager professional summary outgoing quality assurance manager year managerial ex
# Processed text: operation manager special hiring auth veterans pref veoa skill secret security clearance project man
# Processed text: radiological control technician professional summary dynamic college student year nuclear experience
# Processed text: operation technician summary multi faceted mechanical engineering student background ordnance small
# Processed text: tso floater career overview obtain position provide family finish call duty term service indebte cou
# Processed text: entrepreneur general manager professional summary airport operation safety training coordinator mana
# Processed text: international certification program management profile experienced professional year aviation aerosp
# Processed text: recruiter charge summary accomplished detail orient professional offering excellent organizational s
# Processed text: customer service rep career focus find long term career enjoyable great place work able support fami
# Processed text: senior aerospace quality engineer profile six sigma black belt total quality management spc qfd mist
# Processed text: program manager highlight microsoft office word access excel outlook powerpoint advance gfebs window
# Processed text: operator summary atp ess testing training lean six sigma event operate wire cutting aqueous cleaning
# Processed text: afscme union president summary focus operation manager union president successful contract negotiati
# Processed text: security baggage handler personnel screener career overview highly enthusiastic customer service pro
# Processed text: bakery entrepreneur summary comprehensive experience manufacturing reliability engineering nuclear p
# Processed text: bank teller professional summary personable high energy nursing professional ambitious individual de
# Processed text: electrical engineer summary season electrical engineer successful coordinate diverse project improve
# Processed text: plant operator summary certify plant operator year cryogenic air separation unit plant prove ability
# Processed text: customer service representative career focus dedicated skilled cash administrator excel prioritizing
# Processed text: maintenance specialist technician summary military veteran journeyman electrician seek retain curren
# Processed text: material control specialist summary accomplish professional year experience within field logistic ye
# Processed text: desktop support engineer profile dedicated system center administrator desktop support engineer nine
# Processed text: storekeeper ii professional summary purpose document secure responsible career position fully utiliz
# Processed text: maintenance mechanic summary graduate associate apply science power plant airframe technology faa li
# Processed text: line service technician summary currently fly hour sophomore student southwestern illinois college a
# Processed text: purchaser production coordinator professional profile productive quality orient professional eager c
# Processed text: supervisor summary supervisor two year corrosion control facility us government shift supervisor thr
# Processed text: paralegal summary license paralegal demonstrate confidence tenacity project analysis well sound busi
# Processed text: passenger service officer professional summary hard working self motivate australian professional wi
# Processed text: lead operation engineer global hawk project profile season aerospace professional extensive experien
# Processed text: electrician professional summary technically sophisticated aviation electrician year experience larg
# Processed text: manage pressure drilling field supervisor professional summary detail orient self motivate strong ba
# Processed text: passenger service concourse manager summary dedicated enthusiastic leader able motivate employee per
# Processed text: assistant cfo professional summary dedicated focused office administrator excel prioritize complete
# Processed text: air freight agent summary air freight agent emphasize quality customer service air cargo service har
# Processed text: java intern career overview developer well verse structuring develop implement interactive website e
# Processed text: customer service representative summary obtain position enable use organizational skill ability work
# Processed text: assistant manage director professional profile natalia garcia versatile solution drive professional
# Processed text: non commission security officer summary seek entry level position technology base company use skill
# Processed text: administrative manager professional summary highly skilled bilingual english spanish motivate profes
# Processed text: customer service agent professional summary customer service agent year experience help people every
# Processed text: laborer career focus look entry level job challenge nolan excellent communication skill work well ot
# Processed text: flight manager summary enthusiastic fun dedicated professional exceptional communication account man
# Processed text: gunnery sergeant core qualifications detail orient budget planning window proficient mac proficient
# Processed text: management program analysis professional summary human service degree arcom award successful work bu
# Processed text: supply chain manager summary operation manager fiu college business mba program experience november
# Processed text: entrepreneur general manager summary year experience airport operation safety training extensive kno
# Processed text: personnel security specialist summary dedicated security specialist professional possess excute broa
# Processed text: manager continuous improvement skill fiber optic repair technical skill set formal training learjet
# Processed text: specialist infantry professional summary professional learning occupational consultant life skill co
# Processed text: supervisory logistic management specialist summary target focus highly motivated competent logistic
# Processed text: account executive professional summary account executive accomplish sale management professional yea
# Processed text: production excellence specialist summary result drive skilled quality specialist focus achieve succe
# Processed text: senior lead technologist editor professional profile year experience provide technical support proje
# Processed text: production supervisor value stream leader summary obtain employment within company opportunity growt
# Processed text: p control tech summary seek position warehouse company use experience forklift driver order maintain
# Processed text: advanced level wheel vehicle mechanic career focus obtain challenging rewarding position professiona
# Processed text: rank sgt commission officer charge brigade mail room summary motivate logistic specialist successful
# Processed text: government relation communication organizational development director professional summary strategic
# Processed text: geek squad agent professional profile support specialist experience across multiple discipline inclu
# Processed text: program director office manager summary highly personable tech savvy professional plus year experien
# Processed text: storekeeper ii professional summary purpose document secure responsible career position fully utiliz

# %%
print(df[["Resume_str","Clean_Resume"]].head())
# Out:
#                                           Resume_str  \
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1           HR SPECIALIST, US HR OPERATIONS      ...
# 2           HR DIRECTOR       Summary      Over 2...
# 3           HR SPECIALIST       Summary    Dedica...
# 4           HR MANAGER         Skill Highlights  ...
#
#                                         Clean_Resume
# 0  hr administrator marketing associate hr admini...
# 1  hr specialist us hr operation summary versatil...
# 2  hr director summary year experience recruiting...
# 3  hr specialist summary dedicated drive dynamic ...
# 4  hr manager skill highlight hr skill hr departm...

# %%
df = df.drop(columns=["Clean_Resume"])

# %%
df.head()
# Out:
#          ID                                         Resume_str Category  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...       HR
# 2  33176873           HR DIRECTOR       Summary      Over 2...       HR
# 3  27018550           HR SPECIALIST       Summary    Dedica...       HR
# 4  17812897           HR MANAGER         Skill Highlights  ...       HR
#
#                                         Clean Resume
# 0  hr administrator marketing associate hr admini...
# 1  hr specialist us hr operation summary versatil...
# 2  hr director summary year experience recruiting...
# 3  hr specialist summary dedicated drive dynamic ...
# 4  hr manager skill highlight hr skill hr departm...
